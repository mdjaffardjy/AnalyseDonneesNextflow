# %% [markdown]
# # **Mesure de similarité des Processes Nextflow**

# %% [markdown]
# #### Une présentation des différents façon de mesure de similarité entre les processes de Nextflow (présentation des idéés + fonctions pour faire fonctionner)

# %% [markdown]
# Dans la suite *p1* et *p2* font référencent à des process qui sont lu à partir du fichier json, une exemple sera présenté à la fin pour montrer comment utiliser les fonctions

# %% [markdown]
# ___

# %% [markdown]
# Usefull links :
#
# * <ins> Hypothèse 1</ins>:
#   - https://en.wikipedia.org/wiki/Cosine_similarity
#   - https://en.wikipedia.org/wiki/Overlap_coefficient
#   - https://en.wikipedia.org/wiki/S%C3%B8rensen%E2%80%93Dice_coefficient
#   - https://en.wikipedia.org/wiki/Jaccard_index
# * <ins> Hypothèse 3</ins>:
#   - https://fr.wikipedia.org/wiki/Similarit%C3%A9_cosinus
#   - https://fr.wikipedia.org/wiki/Indice_et_distance_de_Jaccard

# %% [markdown]
# ___

# %% [markdown]
# ## *Retrieve data & load libraries*

# %%
import json
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
samba= {}
with open('samba.json') as json_file:
    samba = json.load(json_file)

eager= {}
with open('eager.json') as json_file:
    eager = json.load(json_file)

# %% [markdown]
# ____

# %% [markdown]
# ## *Hypothèse 1 : bio.tools*

# %% [markdown]
# L'idée ici est de comparé si les bio.tools sont identique entre les deux processes
#
# Pour se faire on propose 3 fonctions de score basé sur 3 façons de calcule de similarité :
# - Jaccard index
# - Sørensen–Dice coefficient
# - Overlap coefficient

# %%
def get_tools(p1, p2):
    t1 = p1['tools'].lower()
    t2 = p2['tools'].lower()
    return t1, t2

# %% [markdown]
# ### 1. <ins>Jaccard index</ins>
#
# L'indice de Jaccard (ou coefficient de Jaccard) est le rapport entre le cardinal de l'intersection des ensembles considérés et le cardinal de l'union des ensembles. Il permet d'évaluer la similarité entre les ensembles. Soit deux ensembles $A$ et $B$, l'indice est :
#
# $$ J(A,B) = \frac{|A \cap B|}{|A \cup B|}.$$

# %%
def intersection(l1, l2):
    return list(set(l1) & set(l2))

def union(l1, l2):
    return list(set(l1 + l2))

def min(a, b):
    if(a<b):
        return a
    return b

# %%
def jaccard_tools(p1, p2):
    t1, t2 = get_tools(p1, p2)
    num = len(intersection(t1, t2))
    if(num==0):
        return 0
    denum= len(union(t1, t2))
    return num/denum

# %% [markdown]
# ### 2. <ins>Sørensen–Dice coefficient</ins>
#
# L'indice de Sørensen-Dice est un indicateur statistique qui mesure la similarité de deux échantillons.
#
# Pour des ensembles finis quelconques X et Y, l'indice s'exprime par :
#
# $$ s = \frac{2 |X \cap Y|}{|X| + |Y|}$$

# %%
def soresen_tools(p1, p2):
    t1, t2 = get_tools(p1, p2)
    num = 2*len(intersection(t1, t2))
    if(num==0):
        return 0
    denum= len(t1) + len(t2)
    return num/denum

# %% [markdown]
# ### 3. <ins>Overlap coefficient</ins>
#
# Le coefficient de chevauchement est une mesure de similarité qui mesure le chevauchement entre deux ensembles finis. Il est défini comme la taille de l'intersection divisée par la plus petite des tailles des deux ensembles :
#
# $$ overlap(X,Y) = \frac{|X \cap Y|}{min(|X|, |Y|)}.$$

# %%
def overlap_tools(p1, p2):
    t1, t2 = get_tools(p1, p2)
    num = len(intersection(t1, t2))
    if(num==0):
        return 0
    denum= min(len(t1), len(t2))
    return num/denum

# %% [markdown]
# ___

# %% [markdown]
# ## *Hypothèse 2 : Identité du code*

# %% [markdown]
# L'idée ici est de vérifier si les process et les scripts sont les mêmes

# %% [markdown]
# ### *Hypothèse 2.1 : Identité du code du process*

# %%
def identity_process(p1, p2):
    return p1["string_process"].lower() == p2["string_process"].lower()

# %% [markdown]
# ### *Hypothèse 2.2 : Identité du code du script*

# %%
def identity_process(p1, p2):
    return p1["string_script"].lower() == p2["string_script"].lower()

# %% [markdown]
# ___

# %% [markdown]
# ## *Hypothèse 3 : Similarité du code*

# %% [markdown]
# Pour mesurer la similarité du code (string du process et string du string), on va utiliser plusieurs méthodes (comme dans le cas de l'hypothèse 1) :
# - Similarité cosinus
# - Indice et distance de Jaccard

# %% [markdown]
# ### 0.1 <ins>Similarité cosinus</ins>
#
# La similarité cosinus donne la similarité de deux vecteurs à n dimensions en déterminant le cosinus de leur angle. Ce score est fréquemment utilisée en fouille de textes1.
#
# Soit deux vecteurs A et B, le cosinus de leur angle θ s'obtient en prenant leur produit scalaire divisé par le produit de leurs normes :
#
# $${\displaystyle \cos \theta ={\frac {\mathbf {A} \cdot \mathbf {B} }{\|\mathbf {A} \|\|\mathbf {B} \|}}}$$

# %% [markdown]
# Fonctions écrit ci-dessus est basé sur la fonction présenté ici : https://studymachinelearning.com/cosine-similarity-text-similarity-metric/

# %%
def similarite_cosinus(doc_1, doc_2):
    data = [doc_1.lower(), doc_2.lower()]
    count_vectorizer = CountVectorizer()
    vector_matrix = count_vectorizer.fit_transform(data)
    vector_matrix

    tokens = count_vectorizer.get_feature_names_out()
    tokens

    vector_matrix.toarray()


    def create_dataframe(matrix, tokens):

        doc_names = [f'doc_{i+1}' for i, _ in enumerate(matrix)]
        df = pd.DataFrame(data=matrix, index=doc_names, columns=tokens)
        return(df)

    create_dataframe(vector_matrix.toarray(),tokens)

    cosine_similarity_matrix = cosine_similarity(vector_matrix)

    Tfidf_vect = TfidfVectorizer()
    vector_matrix = Tfidf_vect.fit_transform(data)

    tokens = Tfidf_vect.get_feature_names_out()
    create_dataframe(vector_matrix.toarray(),tokens)

    cosine_similarity_matrix = cosine_similarity(vector_matrix)
    return create_dataframe(cosine_similarity_matrix,['doc_1','doc_2'])['doc_1']['doc_2']

# %% [markdown]
# ### 0.2 <ins>Indice et distance de Jaccard</ins>
#
# L'indice de Jaccard (ou coefficient de Jaccard) est le rapport entre le cardinal de l'intersection des ensembles considérés et le cardinal de l'union des ensembles. Il permet d'évaluer la similarité entre les ensembles. Soit deux ensembles $A$ et $B$, l'indice est :
#
# $$ J(A,B) = \frac{|A \cap B|}{|A \cup B|}.$$

# %%
def jaccard_texts(s1, s2):
    s1 , s2= s1.lower().split(), s2.lower().split()
    num = len(intersection(s1, s2))
    if(num==0):
        return 0
    denum= len(union(s1, s2))
    return num/denum

# %% [markdown]
# ### *Hypothèse 3.1 : Similarité du code du process*

# %% [markdown]
# #### *Hypothèse 3.1.1 : Similarité du code du process avec similarité cosinus*

# %%
def similarite_process_cos(p1, p2):
    return similarite_cosinus(p1["string_process"], p2["string_process"])

# %% [markdown]
# #### *Hypothèse 3.1.2 : Similarité du code du process avec Jacard*

# %%
def similarite_process_jacard(p1, p2):
    return jaccard_texts(p1["string_process"], p2["string_process"])

# %% [markdown]
# ### *Hypothèse 3.2 : Similarité du code du script*

# %% [markdown]
# #### *Hypothèse 3.2.1 : Similarité du code du script avec similarité cosinus*

# %%
def similarite_script_cos(p1, p2):
    return similarite_cosinus(p1["string_script"], p2["string_script"])

# %% [markdown]
# #### *Hypothèse 3.2.2 : Similarité du code du script avec Jacard*

# %%
def similarite_script_jacard(p1, p2):
    return jaccard_texts(p1["string_script"], p2["string_script"])

# %% [markdown]
# ___

# %%
for i in samba:
    for y in eager:
        print(f"{i} - {y} : {similarite_process_cos(samba[i], eager[y])}")
# Out:
# get_test_data - unzip_reference : 0.13010402950224617
# get_test_data - makeBWAIndex : 0.10886952348081849
# get_test_data - makeBT2Index : 0.1055093471785507
# get_test_data - makeFastaIndex : 0.17751372082942563
# get_test_data - makeSeqDict : 0.13992063374329572
# get_test_data - convertBam : 0.07353598363924573
# get_test_data - indexinputbam : 0.132408674041419
# get_test_data - fastqc : 0.0852378616799032
# get_test_data - fastp : 0.12255097404110468
# get_test_data - adapter_removal : 0.1492890091702686
# get_test_data - post_ar_fastq_trimming : 0.1398774189452367
# get_test_data - lanemerge : 0.08624106699847904
# get_test_data - lanemerge_hostremoval_fastq : 0.106567143000243
# get_test_data - fastqc_after_clipping : 0.18372027251810216
# get_test_data - bwa : 0.1202492738902323
# get_test_data - bwamem : 0.0983158263879476
# get_test_data - circulargenerator : 0.24458287262770925
# get_test_data - circularmapper : 0.1642384378107855
# get_test_data - bowtie2 : 0.1335294811677194
# get_test_data - hostremoval_input_fastq : 0.15336270917633604
# get_test_data - seqtype_merge : 0.09143287627219346
# get_test_data - samtools_flagstat : 0.1373295508266693
# get_test_data - samtools_filter : 0.0953433510108735
# get_test_data - samtools_flagstat_after_filter : 0.11487664766996737
# get_test_data - endorSpy : 0.09461152442570019
# get_test_data - dedup : 0.08440860072639118
# get_test_data - markduplicates : 0.07185020071149076
# get_test_data - library_merge : 0.0859103736725492
# get_test_data - preseq : 0.2058614049424633
# get_test_data - bedtools : 0.08860679909471503
# get_test_data - damageprofiler : 0.10489453045534865
# get_test_data - mapdamage_rescaling : 0.14302281437011366
# get_test_data - pmdtools : 0.1563970461466609
# get_test_data - bam_trim : 0.17980759558803974
# get_test_data - additional_library_merge : 0.06456871346598463
# get_test_data - qualimap : 0.16112732101641783
# get_test_data - genotyping_ug : 0.1513573620473189
# get_test_data - genotyping_hc : 0.2172698131522766
# get_test_data - genotyping_freebayes : 0.22989969538160457
# get_test_data - genotyping_pileupcaller : 0.15934337336206097
# get_test_data - eigenstrat_snp_coverage : 0.0854465107166619
# get_test_data - genotyping_angsd : 0.15223379799024273
# get_test_data - bcftools_stats : 0.12264527404555109
# get_test_data - vcf2genome : 0.15612276181514292
# get_test_data - multivcfanalyzer : 0.25682106785706876
# get_test_data - mtnucratio : 0.10655238451788959
# get_test_data - sexdeterrmine_prep : 0.11988664180998834
# get_test_data - sexdeterrmine : 0.1510460709934405
# get_test_data - nuclear_contamination : 0.10172652605706343
# get_test_data - print_nuclear_contamination : 0.24560005791144462
# get_test_data - metagenomic_complexity_filter : 0.13508538504544051
# get_test_data - malt : 0.27884482290114
# get_test_data - maltextract : 0.2799111209980609
# get_test_data - decomp_kraken : 0.0520504005038939
# get_test_data - kraken : 0.15770766789381505
# get_test_data - kraken_parse : 0.0716595341243761
# get_test_data - kraken_merge : 0.12033869996630901
# get_test_data - output_documentation : 0.1973971178090364
# get_test_data - get_software_versions : 0.02600382032190937
# get_test_data - multiqc : 0.13502593020836745
# data_integrity - unzip_reference : 0.12564652645144525
# data_integrity - makeBWAIndex : 0.22187754990967973
# data_integrity - makeBT2Index : 0.2147862524255215
# data_integrity - makeFastaIndex : 0.3597700769930797
# data_integrity - makeSeqDict : 0.2820094106850779
# data_integrity - convertBam : 0.07892546976175485
# data_integrity - indexinputbam : 0.14511718698289566
# data_integrity - fastqc : 0.13110863980298967
# data_integrity - fastp : 0.1913940718754234
# data_integrity - adapter_removal : 0.2592918054827476
# data_integrity - post_ar_fastq_trimming : 0.2631279701723304
# data_integrity - lanemerge : 0.1415938058900824
# data_integrity - lanemerge_hostremoval_fastq : 0.09832185673086957
# data_integrity - fastqc_after_clipping : 0.3169727845053973
# data_integrity - bwa : 0.2570726244949283
# data_integrity - bwamem : 0.17805770036009538
# data_integrity - circulargenerator : 0.4012280220026035
# data_integrity - circularmapper : 0.307185529228123
# data_integrity - bowtie2 : 0.2328486253186573
# data_integrity - hostremoval_input_fastq : 0.23576888398388346
# data_integrity - seqtype_merge : 0.08531799505501417
# data_integrity - samtools_flagstat : 0.20295488147035623
# data_integrity - samtools_filter : 0.19191615736850257
# data_integrity - samtools_flagstat_after_filter : 0.19953813395092834
# data_integrity - endorSpy : 0.17898252981342255
# data_integrity - dedup : 0.13255301407660067
# data_integrity - markduplicates : 0.11365602263485781
# data_integrity - library_merge : 0.1302689849017218
# data_integrity - preseq : 0.43654023476885445
# data_integrity - bedtools : 0.18741290752629503
# data_integrity - damageprofiler : 0.19037010554338807
# data_integrity - mapdamage_rescaling : 0.24310962798071023
# data_integrity - pmdtools : 0.2799338496151296
# data_integrity - bam_trim : 0.30966812512522146
# data_integrity - additional_library_merge : 0.11298048248260197
# data_integrity - qualimap : 0.30107243058682603
# data_integrity - genotyping_ug : 0.29208569214358043
# data_integrity - genotyping_hc : 0.40674289548703024
# data_integrity - genotyping_freebayes : 0.3873210203247523
# data_integrity - genotyping_pileupcaller : 0.276857834043882
# data_integrity - eigenstrat_snp_coverage : 0.19847098121911394
# data_integrity - genotyping_angsd : 0.2745193125008932
# data_integrity - bcftools_stats : 0.2052674370465996
# data_integrity - vcf2genome : 0.33086586457835043
# data_integrity - multivcfanalyzer : 0.4034046768373485
# data_integrity - mtnucratio : 0.1930806514182194
# data_integrity - sexdeterrmine_prep : 0.11878319307011029
# data_integrity - sexdeterrmine : 0.30984212139431055
# data_integrity - nuclear_contamination : 0.19296662835975278
# data_integrity - print_nuclear_contamination : 0.4064757729622748
# data_integrity - metagenomic_complexity_filter : 0.21500637523664334
# data_integrity - malt : 0.4989279375230664
# data_integrity - maltextract : 0.48526857680015084
# data_integrity - decomp_kraken : 0.031245728659059092
# data_integrity - kraken : 0.26091769789544783
# data_integrity - kraken_parse : 0.0841034029145306
# data_integrity - kraken_merge : 0.26054470529373297
# data_integrity - output_documentation : 0.35746927191199246
# data_integrity - get_software_versions : 0.09685988203122903
# data_integrity - multiqc : 0.2002486955716148
# q2_import - unzip_reference : 0.1396334530398609
# q2_import - makeBWAIndex : 0.20411324424407465
# q2_import - makeBT2Index : 0.19756385601735624
# q2_import - makeFastaIndex : 0.31138255069155596
# q2_import - makeSeqDict : 0.2514718423300038
# q2_import - convertBam : 0.07669872101301961
# q2_import - indexinputbam : 0.13838787565748334
# q2_import - fastqc : 0.12772656471594404
# q2_import - fastp : 0.17971410786663128
# q2_import - adapter_removal : 0.2135685569826262
# q2_import - post_ar_fastq_trimming : 0.22372558146728144
# q2_import - lanemerge : 0.13275908659439897
# q2_import - lanemerge_hostremoval_fastq : 0.10771188045353373
# q2_import - fastqc_after_clipping : 0.2903659102723495
# q2_import - bwa : 0.19768675020676907
# q2_import - bwamem : 0.14227702908548567
# q2_import - circulargenerator : 0.37661547404543877
# q2_import - circularmapper : 0.25209137760522776
# q2_import - bowtie2 : 0.1862562636182223
# q2_import - hostremoval_input_fastq : 0.2192776371934599
# q2_import - seqtype_merge : 0.09245849432209256
# q2_import - samtools_flagstat : 0.2048781190725278
# q2_import - samtools_filter : 0.15586152218222277
# q2_import - samtools_flagstat_after_filter : 0.18359136667070508
# q2_import - endorSpy : 0.1579144611629996
# q2_import - dedup : 0.11194121325355966
# q2_import - markduplicates : 0.10504656757901591
# q2_import - library_merge : 0.1248933259326459
# q2_import - preseq : 0.3622317575342823
# q2_import - bedtools : 0.1602526102965645
# q2_import - damageprofiler : 0.1712032857075834
# q2_import - mapdamage_rescaling : 0.20485109293160136
# q2_import - pmdtools : 0.23958674454892875
# q2_import - bam_trim : 0.2521332046864887
# q2_import - additional_library_merge : 0.10220536856518363
# q2_import - qualimap : 0.2680321682947025
# q2_import - genotyping_ug : 0.24946616454905723
# q2_import - genotyping_hc : 0.3542990998840794
# q2_import - genotyping_freebayes : 0.34875270533253033
# q2_import - genotyping_pileupcaller : 0.22623694653191548
# q2_import - eigenstrat_snp_coverage : 0.18032348697746636
# q2_import - genotyping_angsd : 0.2347350836797096
# q2_import - bcftools_stats : 0.19354162803959543
# q2_import - vcf2genome : 0.26440996550789647
# q2_import - multivcfanalyzer : 0.3729479779639394
# q2_import - mtnucratio : 0.17370177898418673
# q2_import - sexdeterrmine_prep : 0.12103719297289824
# q2_import - sexdeterrmine : 0.2977064738205539
# q2_import - nuclear_contamination : 0.17413212892408406
# q2_import - print_nuclear_contamination : 0.3884347813212901
# q2_import - metagenomic_complexity_filter : 0.20548050794840844
# q2_import - malt : 0.42758876899561843
# q2_import - maltextract : 0.3907405849026354
# q2_import - decomp_kraken : 0.04402866132663818
# q2_import - kraken : 0.2583750674031293
# q2_import - kraken_parse : 0.08123463263380427
# q2_import - kraken_merge : 0.23159763182144724
# q2_import - output_documentation : 0.3316849977517474
# q2_import - get_software_versions : 0.1453495014701461
# q2_import - multiqc : 0.2020580028544393
# q2_cutadapt - unzip_reference : 0.15034449492430904
# q2_cutadapt - makeBWAIndex : 0.21260841431088257
# q2_cutadapt - makeBT2Index : 0.20589286469874288
# q2_cutadapt - makeFastaIndex : 0.35630633812874424
# q2_cutadapt - makeSeqDict : 0.27936536049336197
# q2_cutadapt - convertBam : 0.09266434315864698
# q2_cutadapt - indexinputbam : 0.15201045327744409
# q2_cutadapt - fastqc : 0.13730346723883793
# q2_cutadapt - fastp : 0.20396845359403004
# q2_cutadapt - adapter_removal : 0.2756966550742344
# q2_cutadapt - post_ar_fastq_trimming : 0.2802849865575078
# q2_cutadapt - lanemerge : 0.1501600308657753
# q2_cutadapt - lanemerge_hostremoval_fastq : 0.10288242184020523
# q2_cutadapt - fastqc_after_clipping : 0.3354133673173888
# q2_cutadapt - bwa : 0.25790064079392583
# q2_cutadapt - bwamem : 0.16669117258356952
# q2_cutadapt - circulargenerator : 0.4111682582535298
# q2_cutadapt - circularmapper : 0.3017300861285019
# q2_cutadapt - bowtie2 : 0.22541702077009285
# q2_cutadapt - hostremoval_input_fastq : 0.23754038764026994
# q2_cutadapt - seqtype_merge : 0.08840718398782528
# q2_cutadapt - samtools_flagstat : 0.20381085271447363
# q2_cutadapt - samtools_filter : 0.20407862311649735
# q2_cutadapt - samtools_flagstat_after_filter : 0.20565290929110167
# q2_cutadapt - endorSpy : 0.17691071650583384
# q2_cutadapt - dedup : 0.13629574990458213
# q2_cutadapt - markduplicates : 0.12358396881248604
# q2_cutadapt - library_merge : 0.13205977030182875
# q2_cutadapt - preseq : 0.4508324611637904
# q2_cutadapt - bedtools : 0.18468884559391152
# q2_cutadapt - damageprofiler : 0.18805092932777037
# q2_cutadapt - mapdamage_rescaling : 0.23080571719109383
# q2_cutadapt - pmdtools : 0.26851246056832107
# q2_cutadapt - bam_trim : 0.29626365882182387
# q2_cutadapt - additional_library_merge : 0.1167409814084319
# q2_cutadapt - qualimap : 0.3045427000663477
# q2_cutadapt - genotyping_ug : 0.30182844826137367
# q2_cutadapt - genotyping_hc : 0.4138137156775649
# q2_cutadapt - genotyping_freebayes : 0.3801214054760201
# q2_cutadapt - genotyping_pileupcaller : 0.2287029274182317
# q2_cutadapt - eigenstrat_snp_coverage : 0.15686479480948154
# q2_cutadapt - genotyping_angsd : 0.2617328002284196
# q2_cutadapt - bcftools_stats : 0.20358686953468785
# q2_cutadapt - vcf2genome : 0.33231195109640554
# q2_cutadapt - multivcfanalyzer : 0.3962859251880353
# q2_cutadapt - mtnucratio : 0.20274817640110884
# q2_cutadapt - sexdeterrmine_prep : 0.1246423219869298
# q2_cutadapt - sexdeterrmine : 0.22348026036301089
# q2_cutadapt - nuclear_contamination : 0.19968847761691794
# q2_cutadapt - print_nuclear_contamination : 0.38201251315484075
# q2_cutadapt - metagenomic_complexity_filter : 0.2423133490819549
# q2_cutadapt - malt : 0.5167985744029033
# q2_cutadapt - maltextract : 0.4644470738127373
# q2_cutadapt - decomp_kraken : 0.0387447402321594
# q2_cutadapt - kraken : 0.27498039060795976
# q2_cutadapt - kraken_parse : 0.09049294960612697
# q2_cutadapt - kraken_merge : 0.24173844503526895
# q2_cutadapt - output_documentation : 0.3224065021315456
# q2_cutadapt - get_software_versions : 0.03281916338909176
# q2_cutadapt - multiqc : 0.1605650496293694
# q2_dada2 - unzip_reference : 0.1623460584963479
# q2_dada2 - makeBWAIndex : 0.188356971610945
# q2_dada2 - makeBT2Index : 0.18240743950166505
# q2_dada2 - makeFastaIndex : 0.3172865555980497
# q2_dada2 - makeSeqDict : 0.24620911367298476
# q2_dada2 - convertBam : 0.08518446669566344
# q2_dada2 - indexinputbam : 0.15399657124362082
# q2_dada2 - fastqc : 0.13161171673619373
# q2_dada2 - fastp : 0.19605562572931254
# q2_dada2 - adapter_removal : 0.2498801969994448
# q2_dada2 - post_ar_fastq_trimming : 0.2509209307351262
# q2_dada2 - lanemerge : 0.13736736654613282
# q2_dada2 - lanemerge_hostremoval_fastq : 0.11755399134868219
# q2_dada2 - fastqc_after_clipping : 0.31560627108934436
# q2_dada2 - bwa : 0.22791295014141444
# q2_dada2 - bwamem : 0.15650093373380636
# q2_dada2 - circulargenerator : 0.3989812180471328
# q2_dada2 - circularmapper : 0.2896492406874831
# q2_dada2 - bowtie2 : 0.21089825582993557
# q2_dada2 - hostremoval_input_fastq : 0.2382441462887661
# q2_dada2 - seqtype_merge : 0.10278680871545083
# q2_dada2 - samtools_flagstat : 0.24212656436652316
# q2_dada2 - samtools_filter : 0.18818550472862294
# q2_dada2 - samtools_flagstat_after_filter : 0.20428926925444488
# q2_dada2 - endorSpy : 0.18669570219065018
# q2_dada2 - dedup : 0.12176460289671841
# q2_dada2 - markduplicates : 0.10964715274738439
# q2_dada2 - library_merge : 0.12821883244781732
# q2_dada2 - preseq : 0.41398103196845226
# q2_dada2 - bedtools : 0.1634714207702488
# q2_dada2 - damageprofiler : 0.17496127482389076
# q2_dada2 - mapdamage_rescaling : 0.21681163289534455
# q2_dada2 - pmdtools : 0.25310063923411985
# q2_dada2 - bam_trim : 0.27848831190388795
# q2_dada2 - additional_library_merge : 0.10254272812427025
# q2_dada2 - qualimap : 0.28033263420722376
# q2_dada2 - genotyping_ug : 0.2848143926173039
# q2_dada2 - genotyping_hc : 0.3955910524137627
# q2_dada2 - genotyping_freebayes : 0.3783939379433232
# q2_dada2 - genotyping_pileupcaller : 0.2258222874242278
# q2_dada2 - eigenstrat_snp_coverage : 0.1389718172653426
# q2_dada2 - genotyping_angsd : 0.25240204772176883
# q2_dada2 - bcftools_stats : 0.2385699361717029
# q2_dada2 - vcf2genome : 0.2976173817634601
# q2_dada2 - multivcfanalyzer : 0.4067393235213899
# q2_dada2 - mtnucratio : 0.17817873144953406
# q2_dada2 - sexdeterrmine_prep : 0.13054888609978457
# q2_dada2 - sexdeterrmine : 0.21953981600037614
# q2_dada2 - nuclear_contamination : 0.1775370131032717
# q2_dada2 - print_nuclear_contamination : 0.3729482421021833
# q2_dada2 - metagenomic_complexity_filter : 0.23473145479173088
# q2_dada2 - malt : 0.48393099545557894
# q2_dada2 - maltextract : 0.4417733626067953
# q2_dada2 - decomp_kraken : 0.041403313541754
# q2_dada2 - kraken : 0.257020378520934
# q2_dada2 - kraken_parse : 0.08788384444117832
# q2_dada2 - kraken_merge : 0.2189376788691313
# q2_dada2 - output_documentation : 0.32019169410716575
# q2_dada2 - get_software_versions : 0.031963245309507525
# q2_dada2 - multiqc : 0.2057842376645825
# q2_dbotu3 - unzip_reference : 0.15838451392477124
# q2_dbotu3 - makeBWAIndex : 0.1806558309704887
# q2_dbotu3 - makeBT2Index : 0.17485912151722405
# q2_dbotu3 - makeFastaIndex : 0.28271118990618566
# q2_dbotu3 - makeSeqDict : 0.22544383582948407
# q2_dbotu3 - convertBam : 0.07833804488584897
# q2_dbotu3 - indexinputbam : 0.14891916028799448
# q2_dbotu3 - fastqc : 0.126888219643222
# q2_dbotu3 - fastp : 0.17975617551866435
# q2_dbotu3 - adapter_removal : 0.20730854238380034
# q2_dbotu3 - post_ar_fastq_trimming : 0.2102132827953606
# q2_dbotu3 - lanemerge : 0.12440762537808965
# q2_dbotu3 - lanemerge_hostremoval_fastq : 0.1253454585355407
# q2_dbotu3 - fastqc_after_clipping : 0.28646271218350283
# q2_dbotu3 - bwa : 0.1853763596741833
# q2_dbotu3 - bwamem : 0.14100596139615298
# q2_dbotu3 - circulargenerator : 0.3735621753045632
# q2_dbotu3 - circularmapper : 0.25602621680515414
# q2_dbotu3 - bowtie2 : 0.18300041552516072
# q2_dbotu3 - hostremoval_input_fastq : 0.22750733413521632
# q2_dbotu3 - seqtype_merge : 0.10921212395705357
# q2_dbotu3 - samtools_flagstat : 0.2056751862434028
# q2_dbotu3 - samtools_filter : 0.15384460059019336
# q2_dbotu3 - samtools_flagstat_after_filter : 0.16719707511222387
# q2_dbotu3 - endorSpy : 0.1439621161273081
# q2_dbotu3 - dedup : 0.10568769743780393
# q2_dbotu3 - markduplicates : 0.09784968698574648
# q2_dbotu3 - library_merge : 0.12448467059420038
# q2_dbotu3 - preseq : 0.3497596760891659
# q2_dbotu3 - bedtools : 0.15137690966448286
# q2_dbotu3 - damageprofiler : 0.16388877308140712
# q2_dbotu3 - mapdamage_rescaling : 0.19976782510995253
# q2_dbotu3 - pmdtools : 0.2313028564868487
# q2_dbotu3 - bam_trim : 0.24764963141115226
# q2_dbotu3 - additional_library_merge : 0.09307866156645514
# q2_dbotu3 - qualimap : 0.25760423915100006
# q2_dbotu3 - genotyping_ug : 0.24932288862060545
# q2_dbotu3 - genotyping_hc : 0.3560570858506523
# q2_dbotu3 - genotyping_freebayes : 0.3609677101098598
# q2_dbotu3 - genotyping_pileupcaller : 0.22680383732889625
# q2_dbotu3 - eigenstrat_snp_coverage : 0.15197349935901788
# q2_dbotu3 - genotyping_angsd : 0.23767003803257003
# q2_dbotu3 - bcftools_stats : 0.18941413790463302
# q2_dbotu3 - vcf2genome : 0.25125213742310565
# q2_dbotu3 - multivcfanalyzer : 0.3908530177216001
# q2_dbotu3 - mtnucratio : 0.1589849225461287
# q2_dbotu3 - sexdeterrmine_prep : 0.13383949442329282
# q2_dbotu3 - sexdeterrmine : 0.27409104295822195
# q2_dbotu3 - nuclear_contamination : 0.15917817380611524
# q2_dbotu3 - print_nuclear_contamination : 0.3789671654889414
# q2_dbotu3 - metagenomic_complexity_filter : 0.1914065359184865
# q2_dbotu3 - malt : 0.42070270930053916
# q2_dbotu3 - maltextract : 0.39113280554994495
# q2_dbotu3 - decomp_kraken : 0.04899263587212234
# q2_dbotu3 - kraken : 0.23505240222224683
# q2_dbotu3 - kraken_parse : 0.08445510219926951
# q2_dbotu3 - kraken_merge : 0.21596644324348166
# q2_dbotu3 - output_documentation : 0.3358247882163066
# q2_dbotu3 - get_software_versions : 0.07183213993488993
# q2_dbotu3 - multiqc : 0.24593272068604338
# q2_dada2_merge - unzip_reference : 0.16028003294562643
# q2_dada2_merge - makeBWAIndex : 0.2229975591126992
# q2_dada2_merge - makeBT2Index : 0.21519287330569298
# q2_dada2_merge - makeFastaIndex : 0.29953947715107265
# q2_dada2_merge - makeSeqDict : 0.2580564561287088
# q2_dada2_merge - convertBam : 0.10180520711625828
# q2_dada2_merge - indexinputbam : 0.14784702862865126
# q2_dada2_merge - fastqc : 0.11513574793048106
# q2_dada2_merge - fastp : 0.16336275082113988
# q2_dada2_merge - adapter_removal : 0.17549749342252385
# q2_dada2_merge - post_ar_fastq_trimming : 0.2097093757944406
# q2_dada2_merge - lanemerge : 0.14551828184209673
# q2_dada2_merge - lanemerge_hostremoval_fastq : 0.09132863261557497
# q2_dada2_merge - fastqc_after_clipping : 0.2534281006827422
# q2_dada2_merge - bwa : 0.1792433557110475
# q2_dada2_merge - bwamem : 0.1341682049890997
# q2_dada2_merge - circulargenerator : 0.2924179512756253
# q2_dada2_merge - circularmapper : 0.19890876346182712
# q2_dada2_merge - bowtie2 : 0.15911655546423867
# q2_dada2_merge - hostremoval_input_fastq : 0.17419059482730995
# q2_dada2_merge - seqtype_merge : 0.07628864661103925
# q2_dada2_merge - samtools_flagstat : 0.18745731137184302
# q2_dada2_merge - samtools_filter : 0.12050976977403462
# q2_dada2_merge - samtools_flagstat_after_filter : 0.20497113505785194
# q2_dada2_merge - endorSpy : 0.1748015325035639
# q2_dada2_merge - dedup : 0.1235641621726928
# q2_dada2_merge - markduplicates : 0.11604745271991657
# q2_dada2_merge - library_merge : 0.11789223480868981
# q2_dada2_merge - preseq : 0.2860442467855572
# q2_dada2_merge - bedtools : 0.1724461367915608
# q2_dada2_merge - damageprofiler : 0.1790659395722371
# q2_dada2_merge - mapdamage_rescaling : 0.2054480291302362
# q2_dada2_merge - pmdtools : 0.20493755141499292
# q2_dada2_merge - bam_trim : 0.21625454491180585
# q2_dada2_merge - additional_library_merge : 0.11913733370173832
# q2_dada2_merge - qualimap : 0.26638817168691076
# q2_dada2_merge - genotyping_ug : 0.19759569314917774
# q2_dada2_merge - genotyping_hc : 0.29277667058022333
# q2_dada2_merge - genotyping_freebayes : 0.297041444222395
# q2_dada2_merge - genotyping_pileupcaller : 0.20575741795096986
# q2_dada2_merge - eigenstrat_snp_coverage : 0.14315827562374286
# q2_dada2_merge - genotyping_angsd : 0.1979593260997649
# q2_dada2_merge - bcftools_stats : 0.19383448938578182
# q2_dada2_merge - vcf2genome : 0.2319694587013382
# q2_dada2_merge - multivcfanalyzer : 0.275169499771292
# q2_dada2_merge - mtnucratio : 0.19518387006970028
# q2_dada2_merge - sexdeterrmine_prep : 0.14242748651194614
# q2_dada2_merge - sexdeterrmine : 0.2117484128399354
# q2_dada2_merge - nuclear_contamination : 0.18473668791356448
# q2_dada2_merge - print_nuclear_contamination : 0.3302594190865446
# q2_dada2_merge - metagenomic_complexity_filter : 0.21844692467076562
# q2_dada2_merge - malt : 0.3648278398552855
# q2_dada2_merge - maltextract : 0.31979794939036243
# q2_dada2_merge - decomp_kraken : 0.08473114643652455
# q2_dada2_merge - kraken : 0.23030570039632936
# q2_dada2_merge - kraken_parse : 0.1092517010799706
# q2_dada2_merge - kraken_merge : 0.218906147108879
# q2_dada2_merge - output_documentation : 0.2815613262650751
# q2_dada2_merge - get_software_versions : 0.02651083681385555
# q2_dada2_merge - multiqc : 0.1845580092154803
# q2_taxonomy - unzip_reference : 0.1551463560983453
# q2_taxonomy - makeBWAIndex : 0.1903011853919485
# q2_taxonomy - makeBT2Index : 0.1842902424295504
# q2_taxonomy - makeFastaIndex : 0.31246161950477197
# q2_taxonomy - makeSeqDict : 0.244685656809114
# q2_taxonomy - convertBam : 0.0799333104341083
# q2_taxonomy - indexinputbam : 0.1458588436332641
# q2_taxonomy - fastqc : 0.13303847709231179
# q2_taxonomy - fastp : 0.19547814773226846
# q2_taxonomy - adapter_removal : 0.2409479406992859
# q2_taxonomy - post_ar_fastq_trimming : 0.25092210557312805
# q2_taxonomy - lanemerge : 0.14465514769470075
# q2_taxonomy - lanemerge_hostremoval_fastq : 0.1126535000460928
# q2_taxonomy - fastqc_after_clipping : 0.31407673433445166
# q2_taxonomy - bwa : 0.22081489694222448
# q2_taxonomy - bwamem : 0.15475189757074873
# q2_taxonomy - circulargenerator : 0.39425418717719574
# q2_taxonomy - circularmapper : 0.28423439476293405
# q2_taxonomy - bowtie2 : 0.20489824600082665
# q2_taxonomy - hostremoval_input_fastq : 0.23718680043311835
# q2_taxonomy - seqtype_merge : 0.09864202576719651
# q2_taxonomy - samtools_flagstat : 0.20874620171283345
# q2_taxonomy - samtools_filter : 0.1833605378324736
# q2_taxonomy - samtools_flagstat_after_filter : 0.18556559824778465
# q2_taxonomy - endorSpy : 0.16056734085703708
# q2_taxonomy - dedup : 0.12045140388794284
# q2_taxonomy - markduplicates : 0.11626666749130755
# q2_taxonomy - library_merge : 0.1300671700346931
# q2_taxonomy - preseq : 0.398976486021441
# q2_taxonomy - bedtools : 0.16451751053300648
# q2_taxonomy - damageprofiler : 0.18983592840814886
# q2_taxonomy - mapdamage_rescaling : 0.21559935534201788
# q2_taxonomy - pmdtools : 0.24777334082371835
# q2_taxonomy - bam_trim : 0.27405972025144354
# q2_taxonomy - additional_library_merge : 0.10461172903051616
# q2_taxonomy - qualimap : 0.28230732323693863
# q2_taxonomy - genotyping_ug : 0.2817691827500032
# q2_taxonomy - genotyping_hc : 0.39009440079135227
# q2_taxonomy - genotyping_freebayes : 0.3728514746807386
# q2_taxonomy - genotyping_pileupcaller : 0.22290439715038973
# q2_taxonomy - eigenstrat_snp_coverage : 0.14040627928704288
# q2_taxonomy - genotyping_angsd : 0.24764117556937143
# q2_taxonomy - bcftools_stats : 0.19646052612492215
# q2_taxonomy - vcf2genome : 0.28849985561635366
# q2_taxonomy - multivcfanalyzer : 0.4532792147890501
# q2_taxonomy - mtnucratio : 0.17956378697228706
# q2_taxonomy - sexdeterrmine_prep : 0.12395285812420487
# q2_taxonomy - sexdeterrmine : 0.22252216287909413
# q2_taxonomy - nuclear_contamination : 0.1765866124700287
# q2_taxonomy - print_nuclear_contamination : 0.37885717852261347
# q2_taxonomy - metagenomic_complexity_filter : 0.21601658550687894
# q2_taxonomy - malt : 0.47818318838224183
# q2_taxonomy - maltextract : 0.43732608360652075
# q2_taxonomy - decomp_kraken : 0.03980126517251608
# q2_taxonomy - kraken : 0.2551569299732473
# q2_taxonomy - kraken_parse : 0.08318199203501053
# q2_taxonomy - kraken_merge : 0.22740905993780766
# q2_taxonomy - output_documentation : 0.32749949890375496
# q2_taxonomy - get_software_versions : 0.06254880726656055
# q2_taxonomy - multiqc : 0.20332394007180093
# q2_filtering_tax - unzip_reference : 0.14900686302833419
# q2_filtering_tax - makeBWAIndex : 0.16560319803678078
# q2_filtering_tax - makeBT2Index : 0.16028948290013798
# q2_filtering_tax - makeFastaIndex : 0.2532133987345868
# q2_filtering_tax - makeSeqDict : 0.20366806483134647
# q2_filtering_tax - convertBam : 0.07056242881246202
# q2_filtering_tax - indexinputbam : 0.13758063623181968
# q2_filtering_tax - fastqc : 0.12480780551281674
# q2_filtering_tax - fastp : 0.17223778596619632
# q2_filtering_tax - adapter_removal : 0.18398109372537366
# q2_filtering_tax - post_ar_fastq_trimming : 0.19046733889476078
# q2_filtering_tax - lanemerge : 0.11770378265739011
# q2_filtering_tax - lanemerge_hostremoval_fastq : 0.12215577051808603
# q2_filtering_tax - fastqc_after_clipping : 0.27461918206972996
# q2_filtering_tax - bwa : 0.16650892831980654
# q2_filtering_tax - bwamem : 0.13543679570643682
# q2_filtering_tax - circulargenerator : 0.3500426275747946
# q2_filtering_tax - circularmapper : 0.24099396339048035
# q2_filtering_tax - bowtie2 : 0.16727941713941985
# q2_filtering_tax - hostremoval_input_fastq : 0.22306751693727708
# q2_filtering_tax - seqtype_merge : 0.10743989805231445
# q2_filtering_tax - samtools_flagstat : 0.20779833670809053
# q2_filtering_tax - samtools_filter : 0.1389643909298022
# q2_filtering_tax - samtools_flagstat_after_filter : 0.1606501247157804
# q2_filtering_tax - endorSpy : 0.1387224657780557
# q2_filtering_tax - dedup : 0.09697277187026725
# q2_filtering_tax - markduplicates : 0.09054879911188245
# q2_filtering_tax - library_merge : 0.12302951681978551
# q2_filtering_tax - preseq : 0.31145930426971485
# q2_filtering_tax - bedtools : 0.15137360184358015
# q2_filtering_tax - damageprofiler : 0.15432632050460526
# q2_filtering_tax - mapdamage_rescaling : 0.19106500703088714
# q2_filtering_tax - pmdtools : 0.21246513171960005
# q2_filtering_tax - bam_trim : 0.2317194907872671
# q2_filtering_tax - additional_library_merge : 0.08943397232871633
# q2_filtering_tax - qualimap : 0.25086104435073014
# q2_filtering_tax - genotyping_ug : 0.23578745580477908
# q2_filtering_tax - genotyping_hc : 0.3381508714746242
# q2_filtering_tax - genotyping_freebayes : 0.35352749335612815
# q2_filtering_tax - genotyping_pileupcaller : 0.22143644708991694
# q2_filtering_tax - eigenstrat_snp_coverage : 0.1320303251211383
# q2_filtering_tax - genotyping_angsd : 0.2327584443488715
# q2_filtering_tax - bcftools_stats : 0.18829823620235672
# q2_filtering_tax - vcf2genome : 0.2346541807602513
# q2_filtering_tax - multivcfanalyzer : 0.39988153484324646
# q2_filtering_tax - mtnucratio : 0.15013997180061725
# q2_filtering_tax - sexdeterrmine_prep : 0.12606728830915073
# q2_filtering_tax - sexdeterrmine : 0.2535950020457222
# q2_filtering_tax - nuclear_contamination : 0.1497778744918252
# q2_filtering_tax - print_nuclear_contamination : 0.3684158220599158
# q2_filtering_tax - metagenomic_complexity_filter : 0.17927371067779427
# q2_filtering_tax - malt : 0.38595984899760477
# q2_filtering_tax - maltextract : 0.3666144895323571
# q2_filtering_tax - decomp_kraken : 0.047655780524633
# q2_filtering_tax - kraken : 0.2237721874763948
# q2_filtering_tax - kraken_parse : 0.07711698251103494
# q2_filtering_tax - kraken_merge : 0.220735318318237
# q2_filtering_tax - output_documentation : 0.35002854293785024
# q2_filtering_tax - get_software_versions : 0.06367564370847983
# q2_filtering_tax - multiqc : 0.26995988893847056
# microDecon_step1 - unzip_reference : 0.09240293608513812
# microDecon_step1 - makeBWAIndex : 0.22839163363108334
# microDecon_step1 - makeBT2Index : 0.22109214335984956
# microDecon_step1 - makeFastaIndex : 0.3551746611475127
# microDecon_step1 - makeSeqDict : 0.2817019155192749
# microDecon_step1 - convertBam : 0.0569326377954393
# microDecon_step1 - indexinputbam : 0.1093797664195796
# microDecon_step1 - fastqc : 0.11129024005510495
# microDecon_step1 - fastp : 0.16328488157922758
# microDecon_step1 - adapter_removal : 0.22093615386738263
# microDecon_step1 - post_ar_fastq_trimming : 0.239030289191636
# microDecon_step1 - lanemerge : 0.1324672399739635
# microDecon_step1 - lanemerge_hostremoval_fastq : 0.06779987912591977
# microDecon_step1 - fastqc_after_clipping : 0.26790606625586744
# microDecon_step1 - bwa : 0.2167479527476375
# microDecon_step1 - bwamem : 0.13269964339970536
# microDecon_step1 - circulargenerator : 0.3682258551627414
# microDecon_step1 - circularmapper : 0.2422595151020477
# microDecon_step1 - bowtie2 : 0.19356557029486934
# microDecon_step1 - hostremoval_input_fastq : 0.18750774357633568
# microDecon_step1 - seqtype_merge : 0.058750404650978555
# microDecon_step1 - samtools_flagstat : 0.17276850953961603
# microDecon_step1 - samtools_filter : 0.16005983378425123
# microDecon_step1 - samtools_flagstat_after_filter : 0.18302632521401926
# microDecon_step1 - endorSpy : 0.15889691577986217
# microDecon_step1 - dedup : 0.11024541959418832
# microDecon_step1 - markduplicates : 0.10385803468533275
# microDecon_step1 - library_merge : 0.11232776991951811
# microDecon_step1 - preseq : 0.3903591289884005
# microDecon_step1 - bedtools : 0.14946026698909076
# microDecon_step1 - damageprofiler : 0.17417214862924096
# microDecon_step1 - mapdamage_rescaling : 0.1995285736668054
# microDecon_step1 - pmdtools : 0.2550727462814647
# microDecon_step1 - bam_trim : 0.25034621295733706
# microDecon_step1 - additional_library_merge : 0.10208950728350599
# microDecon_step1 - qualimap : 0.25555301960901794
# microDecon_step1 - genotyping_ug : 0.24123807217625134
# microDecon_step1 - genotyping_hc : 0.3414530362326912
# microDecon_step1 - genotyping_freebayes : 0.3106187001535913
# microDecon_step1 - genotyping_pileupcaller : 0.2168864811552223
# microDecon_step1 - eigenstrat_snp_coverage : 0.22328772711841816
# microDecon_step1 - genotyping_angsd : 0.2190891447773425
# microDecon_step1 - bcftools_stats : 0.17426188307572849
# microDecon_step1 - vcf2genome : 0.2746543806797097
# microDecon_step1 - multivcfanalyzer : 0.3750859520744631
# microDecon_step1 - mtnucratio : 0.17639677246362753
# microDecon_step1 - sexdeterrmine_prep : 0.08240857880142849
# microDecon_step1 - sexdeterrmine : 0.3228400125138432
# microDecon_step1 - nuclear_contamination : 0.174634747398492
# microDecon_step1 - print_nuclear_contamination : 0.3635919537390305
# microDecon_step1 - metagenomic_complexity_filter : 0.19655017856917018
# microDecon_step1 - malt : 0.438942301702578
# microDecon_step1 - maltextract : 0.3845640781790867
# microDecon_step1 - decomp_kraken : 0.01869018189402789
# microDecon_step1 - kraken : 0.2249727082656766
# microDecon_step1 - kraken_parse : 0.06266561256923843
# microDecon_step1 - kraken_merge : 0.2187218730277699
# microDecon_step1 - output_documentation : 0.27348656637060526
# microDecon_step1 - get_software_versions : 0.16917461703901515
# microDecon_step1 - multiqc : 0.11251563830850775
# microDecon_step2 - unzip_reference : 0.12383928282949838
# microDecon_step2 - makeBWAIndex : 0.20932168790000996
# microDecon_step2 - makeBT2Index : 0.20205842138706576
# microDecon_step2 - makeFastaIndex : 0.303679034557968
# microDecon_step2 - makeSeqDict : 0.2485920247138031
# microDecon_step2 - convertBam : 0.09286874332717882
# microDecon_step2 - indexinputbam : 0.1388490382180962
# microDecon_step2 - fastqc : 0.1007754753328216
# microDecon_step2 - fastp : 0.14477428119964902
# microDecon_step2 - adapter_removal : 0.19902605627746817
# microDecon_step2 - post_ar_fastq_trimming : 0.2103858688680972
# microDecon_step2 - lanemerge : 0.1347035518918304
# microDecon_step2 - lanemerge_hostremoval_fastq : 0.07689931825514401
# microDecon_step2 - fastqc_after_clipping : 0.22879570909068475
# microDecon_step2 - bwa : 0.18399747724636722
# microDecon_step2 - bwamem : 0.1209093399182772
# microDecon_step2 - circulargenerator : 0.27392880735920494
# microDecon_step2 - circularmapper : 0.18806968623522305
# microDecon_step2 - bowtie2 : 0.15960161249474325
# microDecon_step2 - hostremoval_input_fastq : 0.15362573854990638
# microDecon_step2 - seqtype_merge : 0.0621095747791284
# microDecon_step2 - samtools_flagstat : 0.1630346278383603
# microDecon_step2 - samtools_filter : 0.11971264316716412
# microDecon_step2 - samtools_flagstat_after_filter : 0.19583925247320055
# microDecon_step2 - endorSpy : 0.16641103203797408
# microDecon_step2 - dedup : 0.10269696499698217
# microDecon_step2 - markduplicates : 0.11587219915031922
# microDecon_step2 - library_merge : 0.10644600320130015
# microDecon_step2 - preseq : 0.3458239231511028
# microDecon_step2 - bedtools : 0.1570639803106934
# microDecon_step2 - damageprofiler : 0.1633413085388727
# microDecon_step2 - mapdamage_rescaling : 0.1948413071487706
# microDecon_step2 - pmdtools : 0.20703092640397883
# microDecon_step2 - bam_trim : 0.21403519859931053
# microDecon_step2 - additional_library_merge : 0.11013461418732885
# microDecon_step2 - qualimap : 0.2391496409334593
# microDecon_step2 - genotyping_ug : 0.17989326965228664
# microDecon_step2 - genotyping_hc : 0.2768937794423928
# microDecon_step2 - genotyping_freebayes : 0.2648711260122942
# microDecon_step2 - genotyping_pileupcaller : 0.18003873607630172
# microDecon_step2 - eigenstrat_snp_coverage : 0.14030252942765561
# microDecon_step2 - genotyping_angsd : 0.18723070823809596
# microDecon_step2 - bcftools_stats : 0.173966267964605
# microDecon_step2 - vcf2genome : 0.23203893257083366
# microDecon_step2 - multivcfanalyzer : 0.24344728308363867
# microDecon_step2 - mtnucratio : 0.18567008859762357
# microDecon_step2 - sexdeterrmine_prep : 0.12678508658008575
# microDecon_step2 - sexdeterrmine : 0.18545741298948917
# microDecon_step2 - nuclear_contamination : 0.2027415484676021
# microDecon_step2 - print_nuclear_contamination : 0.2989629971873272
# microDecon_step2 - metagenomic_complexity_filter : 0.18937403053712654
# microDecon_step2 - malt : 0.3581527700681371
# microDecon_step2 - maltextract : 0.31702767073736465
# microDecon_step2 - decomp_kraken : 0.07572152100697387
# microDecon_step2 - kraken : 0.2133050106305278
# microDecon_step2 - kraken_parse : 0.10165845508224866
# microDecon_step2 - kraken_merge : 0.21222585246590087
# microDecon_step2 - output_documentation : 0.24927388179454554
# microDecon_step2 - get_software_versions : 0.02095701616651622
# microDecon_step2 - multiqc : 0.10725037017050149
# microDecon_step3 - unzip_reference : 0.13070297180697035
# microDecon_step3 - makeBWAIndex : 0.28948250070502096
# microDecon_step3 - makeBT2Index : 0.3025763976410699
# microDecon_step3 - makeFastaIndex : 0.3960767893331507
# microDecon_step3 - makeSeqDict : 0.35539289518612727
# microDecon_step3 - convertBam : 0.06549742481469513
# microDecon_step3 - indexinputbam : 0.12107970264814844
# microDecon_step3 - fastqc : 0.10865825767112079
# microDecon_step3 - fastp : 0.15469033950629416
# microDecon_step3 - adapter_removal : 0.2023443229214579
# microDecon_step3 - post_ar_fastq_trimming : 0.21263616602306182
# microDecon_step3 - lanemerge : 0.12167026303444543
# microDecon_step3 - lanemerge_hostremoval_fastq : 0.08537344011763719
# microDecon_step3 - fastqc_after_clipping : 0.25032386411918683
# microDecon_step3 - bwa : 0.2316060387505123
# microDecon_step3 - bwamem : 0.15517968646617603
# microDecon_step3 - circulargenerator : 0.4309312943786061
# microDecon_step3 - circularmapper : 0.2615792777381969
# microDecon_step3 - bowtie2 : 0.1929879896320377
# microDecon_step3 - hostremoval_input_fastq : 0.18541583931240288
# microDecon_step3 - seqtype_merge : 0.06986845150807594
# microDecon_step3 - samtools_flagstat : 0.1739750249215864
# microDecon_step3 - samtools_filter : 0.14069897438503126
# microDecon_step3 - samtools_flagstat_after_filter : 0.17241258102168971
# microDecon_step3 - endorSpy : 0.14753787667743934
# microDecon_step3 - dedup : 0.09347009661446173
# microDecon_step3 - markduplicates : 0.09586426601499118
# microDecon_step3 - library_merge : 0.10723175984370742
# microDecon_step3 - preseq : 0.35587820864935243
# microDecon_step3 - bedtools : 0.1470768514361059
# microDecon_step3 - damageprofiler : 0.18821822244967965
# microDecon_step3 - mapdamage_rescaling : 0.22380761584584125
# microDecon_step3 - pmdtools : 0.26751870996606175
# microDecon_step3 - bam_trim : 0.23232334433556287
# microDecon_step3 - additional_library_merge : 0.09383370208917809
# microDecon_step3 - qualimap : 0.26621885192443995
# microDecon_step3 - genotyping_ug : 0.2608193296285444
# microDecon_step3 - genotyping_hc : 0.36178597488081377
# microDecon_step3 - genotyping_freebayes : 0.352676823461895
# microDecon_step3 - genotyping_pileupcaller : 0.24846972482256366
# microDecon_step3 - eigenstrat_snp_coverage : 0.1996674672934487
# microDecon_step3 - genotyping_angsd : 0.23522038328739306
# microDecon_step3 - bcftools_stats : 0.218415619947365
# microDecon_step3 - vcf2genome : 0.33698937561417225
# microDecon_step3 - multivcfanalyzer : 0.42168172800599246
# microDecon_step3 - mtnucratio : 0.16242622668438417
# microDecon_step3 - sexdeterrmine_prep : 0.10087280851884661
# microDecon_step3 - sexdeterrmine : 0.3088725265051511
# microDecon_step3 - nuclear_contamination : 0.16760705215798097
# microDecon_step3 - print_nuclear_contamination : 0.354336812051519
# microDecon_step3 - metagenomic_complexity_filter : 0.17704569407324322
# microDecon_step3 - malt : 0.3936581548404853
# microDecon_step3 - maltextract : 0.35836594716454667
# microDecon_step3 - decomp_kraken : 0.03162063472488389
# microDecon_step3 - kraken : 0.22189333772329747
# microDecon_step3 - kraken_parse : 0.06980810301681396
# microDecon_step3 - kraken_merge : 0.211878236431361
# microDecon_step3 - output_documentation : 0.29245515631271524
# microDecon_step3 - get_software_versions : 0.13440198426021419
# microDecon_step3 - multiqc : 0.16584470485233296
# microDecon_step4 - unzip_reference : 0.1616468027338013
# microDecon_step4 - makeBWAIndex : 0.2476220183848462
# microDecon_step4 - makeBT2Index : 0.23902976627735578
# microDecon_step4 - makeFastaIndex : 0.353035474250525
# microDecon_step4 - makeSeqDict : 0.2925584781316808
# microDecon_step4 - convertBam : 0.11951533107119659
# microDecon_step4 - indexinputbam : 0.17775665002245009
# microDecon_step4 - fastqc : 0.11913593542838409
# microDecon_step4 - fastp : 0.17208621183620598
# microDecon_step4 - adapter_removal : 0.24105911612864658
# microDecon_step4 - post_ar_fastq_trimming : 0.24241761668978995
# microDecon_step4 - lanemerge : 0.15839741998809048
# microDecon_step4 - lanemerge_hostremoval_fastq : 0.10079650397548258
# microDecon_step4 - fastqc_after_clipping : 0.2673714293583878
# microDecon_step4 - bwa : 0.21083409052989302
# microDecon_step4 - bwamem : 0.14429933852889285
# microDecon_step4 - circulargenerator : 0.31547937735355064
# microDecon_step4 - circularmapper : 0.21806966565815578
# microDecon_step4 - bowtie2 : 0.18416458729483504
# microDecon_step4 - hostremoval_input_fastq : 0.18186176257822242
# microDecon_step4 - seqtype_merge : 0.07853927906946105
# microDecon_step4 - samtools_flagstat : 0.19228128241152195
# microDecon_step4 - samtools_filter : 0.1357348339040135
# microDecon_step4 - samtools_flagstat_after_filter : 0.2293676947989763
# microDecon_step4 - endorSpy : 0.1929516829891981
# microDecon_step4 - dedup : 0.12302518298589822
# microDecon_step4 - markduplicates : 0.13880837183324124
# microDecon_step4 - library_merge : 0.12342567466993794
# microDecon_step4 - preseq : 0.38770522436788185
# microDecon_step4 - bedtools : 0.1879241964644464
# microDecon_step4 - damageprofiler : 0.19831968632036087
# microDecon_step4 - mapdamage_rescaling : 0.23253349789748026
# microDecon_step4 - pmdtools : 0.23829180310519435
# microDecon_step4 - bam_trim : 0.24919684809202497
# microDecon_step4 - additional_library_merge : 0.129650791458396
# microDecon_step4 - qualimap : 0.28122485536998176
# microDecon_step4 - genotyping_ug : 0.20698048530943092
# microDecon_step4 - genotyping_hc : 0.32501997015884554
# microDecon_step4 - genotyping_freebayes : 0.31787283029086044
# microDecon_step4 - genotyping_pileupcaller : 0.21882377075047227
# microDecon_step4 - eigenstrat_snp_coverage : 0.16324886291481477
# microDecon_step4 - genotyping_angsd : 0.22238396302595723
# microDecon_step4 - bcftools_stats : 0.20718490499105324
# microDecon_step4 - vcf2genome : 0.26679808821385065
# microDecon_step4 - multivcfanalyzer : 0.2928705795419859
# microDecon_step4 - mtnucratio : 0.21882518790896108
# microDecon_step4 - sexdeterrmine_prep : 0.16772260221790006
# microDecon_step4 - sexdeterrmine : 0.22391103666960582
# microDecon_step4 - nuclear_contamination : 0.2321749864961889
# microDecon_step4 - print_nuclear_contamination : 0.35343158849666473
# microDecon_step4 - metagenomic_complexity_filter : 0.2217956017016336
# microDecon_step4 - malt : 0.4157763261982297
# microDecon_step4 - maltextract : 0.3665352101779476
# microDecon_step4 - decomp_kraken : 0.09108675698770806
# microDecon_step4 - kraken : 0.25571907741615163
# microDecon_step4 - kraken_parse : 0.12735048965716755
# microDecon_step4 - kraken_merge : 0.238750628326054
# microDecon_step4 - output_documentation : 0.29063459298092614
# microDecon_step4 - get_software_versions : 0.023866927474008585
# microDecon_step4 - multiqc : 0.15369206587621448
# lr_mapping - unzip_reference : 0.12445528464249206
# lr_mapping - makeBWAIndex : 0.14610530041386863
# lr_mapping - makeBT2Index : 0.13800549771468562
# lr_mapping - makeFastaIndex : 0.21722175719975823
# lr_mapping - makeSeqDict : 0.17087581168943597
# lr_mapping - convertBam : 0.16146300532819538
# lr_mapping - indexinputbam : 0.21777308653738225
# lr_mapping - fastqc : 0.09430564888922686
# lr_mapping - fastp : 0.13470637375106798
# lr_mapping - adapter_removal : 0.15339742347780205
# lr_mapping - post_ar_fastq_trimming : 0.15149952746948836
# lr_mapping - lanemerge : 0.09121672704251724
# lr_mapping - lanemerge_hostremoval_fastq : 0.0941259172295873
# lr_mapping - fastqc_after_clipping : 0.21275926143676208
# lr_mapping - bwa : 0.20975400589591356
# lr_mapping - bwamem : 0.216048006897153
# lr_mapping - circulargenerator : 0.2728748663298356
# lr_mapping - circularmapper : 0.27731126023764874
# lr_mapping - bowtie2 : 0.19709502471368823
# lr_mapping - hostremoval_input_fastq : 0.3092619124080586
# lr_mapping - seqtype_merge : 0.19107816280320897
# lr_mapping - samtools_flagstat : 0.2316375838602042
# lr_mapping - samtools_filter : 0.32861959375672967
# lr_mapping - samtools_flagstat_after_filter : 0.19009819813233428
# lr_mapping - endorSpy : 0.10683900156032852
# lr_mapping - dedup : 0.219196184846556
# lr_mapping - markduplicates : 0.16968311861881885
# lr_mapping - library_merge : 0.20808535213368282
# lr_mapping - preseq : 0.2374052465650247
# lr_mapping - bedtools : 0.20709385229664243
# lr_mapping - damageprofiler : 0.16073568581820047
# lr_mapping - mapdamage_rescaling : 0.2563800662484361
# lr_mapping - pmdtools : 0.29326966172719543
# lr_mapping - bam_trim : 0.3372696950948888
# lr_mapping - additional_library_merge : 0.18220910060808168
# lr_mapping - qualimap : 0.2505705226034065
# lr_mapping - genotyping_ug : 0.2871846231327395
# lr_mapping - genotyping_hc : 0.30174245095572244
# lr_mapping - genotyping_freebayes : 0.29974005244572427
# lr_mapping - genotyping_pileupcaller : 0.2054599102717027
# lr_mapping - eigenstrat_snp_coverage : 0.13736595105742663
# lr_mapping - genotyping_angsd : 0.23448611889148574
# lr_mapping - bcftools_stats : 0.13744298441958028
# lr_mapping - vcf2genome : 0.18655046125168295
# lr_mapping - multivcfanalyzer : 0.2983755347339201
# lr_mapping - mtnucratio : 0.14884997473145742
# lr_mapping - sexdeterrmine_prep : 0.24162942045711477
# lr_mapping - sexdeterrmine : 0.30810516749438427
# lr_mapping - nuclear_contamination : 0.13099831475606905
# lr_mapping - print_nuclear_contamination : 0.2860459550019817
# lr_mapping - metagenomic_complexity_filter : 0.17049349832506272
# lr_mapping - malt : 0.3099575035053886
# lr_mapping - maltextract : 0.27837493818750436
# lr_mapping - decomp_kraken : 0.0408103111788824
# lr_mapping - kraken : 0.19631442553206976
# lr_mapping - kraken_parse : 0.0760712537988086
# lr_mapping - kraken_merge : 0.18080034674975895
# lr_mapping - output_documentation : 0.25841288434237114
# lr_mapping - get_software_versions : 0.15298475493899913
# lr_mapping - multiqc : 0.1942211180738203
# lr_getfasta - unzip_reference : 0.12998631608929406
# lr_getfasta - makeBWAIndex : 0.12056749959154932
# lr_getfasta - makeBT2Index : 0.13584381143840993
# lr_getfasta - makeFastaIndex : 0.09677259488151671
# lr_getfasta - makeSeqDict : 0.1262442494531104
# lr_getfasta - convertBam : 0.12252989498466763
# lr_getfasta - indexinputbam : 0.08314698243678052
# lr_getfasta - fastqc : 0.05300462367917771
# lr_getfasta - fastp : 0.059457744244925954
# lr_getfasta - adapter_removal : 0.048519839815445526
# lr_getfasta - post_ar_fastq_trimming : 0.029999025329267584
# lr_getfasta - lanemerge : 0.039237056060638736
# lr_getfasta - lanemerge_hostremoval_fastq : 0.09193533206223962
# lr_getfasta - fastqc_after_clipping : 0.08649801231673106
# lr_getfasta - bwa : 0.05015170317422355
# lr_getfasta - bwamem : 0.07001683295066666
# lr_getfasta - circulargenerator : 0.16144777222080764
# lr_getfasta - circularmapper : 0.08539440682985541
# lr_getfasta - bowtie2 : 0.04015883444772958
# lr_getfasta - hostremoval_input_fastq : 0.09094088442803866
# lr_getfasta - seqtype_merge : 0.08007854938387851
# lr_getfasta - samtools_flagstat : 0.1036163365632836
# lr_getfasta - samtools_filter : 0.045896151975940595
# lr_getfasta - samtools_flagstat_after_filter : 0.057151683720676
# lr_getfasta - endorSpy : 0.05058492120747736
# lr_getfasta - dedup : 0.025051675427380547
# lr_getfasta - markduplicates : 0.038945478835199096
# lr_getfasta - library_merge : 0.05341703708306443
# lr_getfasta - preseq : 0.04456181535045945
# lr_getfasta - bedtools : 0.061159792487545155
# lr_getfasta - damageprofiler : 0.06626612510870246
# lr_getfasta - mapdamage_rescaling : 0.08298515634996696
# lr_getfasta - pmdtools : 0.06855283298980747
# lr_getfasta - bam_trim : 0.05292328139685208
# lr_getfasta - additional_library_merge : 0.0326553989735135
# lr_getfasta - qualimap : 0.09363912148503933
# lr_getfasta - genotyping_ug : 0.08708872411519271
# lr_getfasta - genotyping_hc : 0.11055362603089448
# lr_getfasta - genotyping_freebayes : 0.15499998827979505
# lr_getfasta - genotyping_pileupcaller : 0.10630976571538474
# lr_getfasta - eigenstrat_snp_coverage : 0.036383161010500584
# lr_getfasta - genotyping_angsd : 0.09143597217280866
# lr_getfasta - bcftools_stats : 0.11857301919340053
# lr_getfasta - vcf2genome : 0.11285959959557175
# lr_getfasta - multivcfanalyzer : 0.20513904491558438
# lr_getfasta - mtnucratio : 0.0449473586314855
# lr_getfasta - sexdeterrmine_prep : 0.09825454086822188
# lr_getfasta - sexdeterrmine : 0.0977791572211631
# lr_getfasta - nuclear_contamination : 0.06600495548853579
# lr_getfasta - print_nuclear_contamination : 0.14562898922198705
# lr_getfasta - metagenomic_complexity_filter : 0.12540751601319483
# lr_getfasta - malt : 0.0666384144546905
# lr_getfasta - maltextract : 0.07415270217381974
# lr_getfasta - decomp_kraken : 0.06509060038949224
# lr_getfasta - kraken : 0.13276517002627167
# lr_getfasta - kraken_parse : 0.05747304301853263
# lr_getfasta - kraken_merge : 0.08744823779453291
# lr_getfasta - output_documentation : 0.18537941692534518
# lr_getfasta - get_software_versions : 0.013148182731404766
# lr_getfasta - multiqc : 0.18414876535022348
# lr_get_taxonomy - unzip_reference : 0.1269466453058445
# lr_get_taxonomy - makeBWAIndex : 0.14781765567605462
# lr_get_taxonomy - makeBT2Index : 0.14318475413578438
# lr_get_taxonomy - makeFastaIndex : 0.2298010739706141
# lr_get_taxonomy - makeSeqDict : 0.18033282433741235
# lr_get_taxonomy - convertBam : 0.07128831533010135
# lr_get_taxonomy - indexinputbam : 0.12714127919141782
# lr_get_taxonomy - fastqc : 0.10181781041065284
# lr_get_taxonomy - fastp : 0.1428169741787709
# lr_get_taxonomy - adapter_removal : 0.18032202388026178
# lr_get_taxonomy - post_ar_fastq_trimming : 0.17485474756471678
# lr_get_taxonomy - lanemerge : 0.10843823465590309
# lr_get_taxonomy - lanemerge_hostremoval_fastq : 0.10307325329518671
# lr_get_taxonomy - fastqc_after_clipping : 0.22478567697835755
# lr_get_taxonomy - bwa : 0.15480634718967956
# lr_get_taxonomy - bwamem : 0.1153724358087559
# ...
# stats_beta_deseq2 - unzip_reference : 0.11814171133941415
# stats_beta_deseq2 - makeBWAIndex : 0.17062367772271156
# stats_beta_deseq2 - makeBT2Index : 0.16525521481604755
# stats_beta_deseq2 - makeFastaIndex : 0.27155063955282926
# stats_beta_deseq2 - makeSeqDict : 0.21207420657590548
# stats_beta_deseq2 - convertBam : 0.06458231210782311
# stats_beta_deseq2 - indexinputbam : 0.12265604835187392
# stats_beta_deseq2 - fastqc : 0.11340992126407218
# stats_beta_deseq2 - fastp : 0.16148613375085233
# stats_beta_deseq2 - adapter_removal : 0.1882709241210965
# stats_beta_deseq2 - post_ar_fastq_trimming : 0.20626925714266683
# stats_beta_deseq2 - lanemerge : 0.12634031743277926
# stats_beta_deseq2 - lanemerge_hostremoval_fastq : 0.09402192584693277
# stats_beta_deseq2 - fastqc_after_clipping : 0.25512478152352513
# stats_beta_deseq2 - bwa : 0.18175694073190143
# stats_beta_deseq2 - bwamem : 0.12697244674776495
# stats_beta_deseq2 - circulargenerator : 0.3296640502817685
# stats_beta_deseq2 - circularmapper : 0.22452708836717813
# stats_beta_deseq2 - bowtie2 : 0.17117614075282064
# stats_beta_deseq2 - hostremoval_input_fastq : 0.19547970555139693
# stats_beta_deseq2 - seqtype_merge : 0.07944519256592511
# stats_beta_deseq2 - samtools_flagstat : 0.18785939142333338
# stats_beta_deseq2 - samtools_filter : 0.1368209081397779
# stats_beta_deseq2 - samtools_flagstat_after_filter : 0.1713094187101453
# stats_beta_deseq2 - endorSpy : 0.1480804016827941
# stats_beta_deseq2 - dedup : 0.09854263241739566
# stats_beta_deseq2 - markduplicates : 0.09372634127161776
# stats_beta_deseq2 - library_merge : 0.11444543688876815
# stats_beta_deseq2 - preseq : 0.33353512250035766
# stats_beta_deseq2 - bedtools : 0.14205778605010552
# stats_beta_deseq2 - damageprofiler : 0.15033313695983644
# stats_beta_deseq2 - mapdamage_rescaling : 0.1894461737913475
# stats_beta_deseq2 - pmdtools : 0.21168322059196867
# stats_beta_deseq2 - bam_trim : 0.2304337128801693
# stats_beta_deseq2 - additional_library_merge : 0.09405711930486975
# stats_beta_deseq2 - qualimap : 0.24142348764575486
# stats_beta_deseq2 - genotyping_ug : 0.21654887621372396
# stats_beta_deseq2 - genotyping_hc : 0.3185091502280104
# stats_beta_deseq2 - genotyping_freebayes : 0.3178491293831732
# stats_beta_deseq2 - genotyping_pileupcaller : 0.19987367295817635
# stats_beta_deseq2 - eigenstrat_snp_coverage : 0.12931158369358728
# stats_beta_deseq2 - genotyping_angsd : 0.2144695751807847
# stats_beta_deseq2 - bcftools_stats : 0.17852607800355744
# stats_beta_deseq2 - vcf2genome : 0.2345783415795526
# stats_beta_deseq2 - multivcfanalyzer : 0.348839527028613
# stats_beta_deseq2 - mtnucratio : 0.15953250084031226
# stats_beta_deseq2 - sexdeterrmine_prep : 0.10250115416114923
# stats_beta_deseq2 - sexdeterrmine : 0.19748141801184996
# stats_beta_deseq2 - nuclear_contamination : 0.1628447741792435
# stats_beta_deseq2 - print_nuclear_contamination : 0.3306246746990011
# stats_beta_deseq2 - metagenomic_complexity_filter : 0.18006942955409405
# stats_beta_deseq2 - malt : 0.38837124671907447
# stats_beta_deseq2 - maltextract : 0.3515364109093766
# stats_beta_deseq2 - decomp_kraken : 0.03287921334042406
# stats_beta_deseq2 - kraken : 0.2196722493879216
# stats_beta_deseq2 - kraken_parse : 0.07555433904227277
# stats_beta_deseq2 - kraken_merge : 0.2144190880610615
# stats_beta_deseq2 - output_documentation : 0.29760434189687757
# stats_beta_deseq2 - get_software_versions : 0.028429287775453064
# stats_beta_deseq2 - multiqc : 0.1852444670836579
# stats_beta_css - unzip_reference : 0.11814171133941415
# stats_beta_css - makeBWAIndex : 0.17062367772271156
# stats_beta_css - makeBT2Index : 0.16525521481604755
# stats_beta_css - makeFastaIndex : 0.27155063955282926
# stats_beta_css - makeSeqDict : 0.21207420657590548
# stats_beta_css - convertBam : 0.06458231210782311
# stats_beta_css - indexinputbam : 0.12265604835187392
# stats_beta_css - fastqc : 0.11340992126407218
# stats_beta_css - fastp : 0.16148613375085233
# stats_beta_css - adapter_removal : 0.1882709241210965
# stats_beta_css - post_ar_fastq_trimming : 0.20626925714266683
# stats_beta_css - lanemerge : 0.12634031743277926
# stats_beta_css - lanemerge_hostremoval_fastq : 0.09402192584693277
# stats_beta_css - fastqc_after_clipping : 0.25512478152352513
# stats_beta_css - bwa : 0.18175694073190143
# stats_beta_css - bwamem : 0.12697244674776495
# stats_beta_css - circulargenerator : 0.3296640502817685
# stats_beta_css - circularmapper : 0.22452708836717813
# stats_beta_css - bowtie2 : 0.17117614075282064
# stats_beta_css - hostremoval_input_fastq : 0.19547970555139693
# stats_beta_css - seqtype_merge : 0.07944519256592511
# stats_beta_css - samtools_flagstat : 0.18785939142333338
# stats_beta_css - samtools_filter : 0.1368209081397779
# stats_beta_css - samtools_flagstat_after_filter : 0.1713094187101453
# stats_beta_css - endorSpy : 0.1480804016827941
# stats_beta_css - dedup : 0.09854263241739566
# stats_beta_css - markduplicates : 0.09372634127161776
# stats_beta_css - library_merge : 0.11444543688876815
# stats_beta_css - preseq : 0.33353512250035766
# stats_beta_css - bedtools : 0.14205778605010552
# stats_beta_css - damageprofiler : 0.15033313695983644
# stats_beta_css - mapdamage_rescaling : 0.1894461737913475
# stats_beta_css - pmdtools : 0.21168322059196867
# stats_beta_css - bam_trim : 0.2304337128801693
# stats_beta_css - additional_library_merge : 0.09405711930486975
# stats_beta_css - qualimap : 0.24142348764575486
# stats_beta_css - genotyping_ug : 0.21654887621372396
# stats_beta_css - genotyping_hc : 0.3185091502280104
# stats_beta_css - genotyping_freebayes : 0.3178491293831732
# stats_beta_css - genotyping_pileupcaller : 0.19987367295817635
# stats_beta_css - eigenstrat_snp_coverage : 0.12931158369358728
# stats_beta_css - genotyping_angsd : 0.2144695751807847
# stats_beta_css - bcftools_stats : 0.17852607800355744
# stats_beta_css - vcf2genome : 0.2345783415795526
# stats_beta_css - multivcfanalyzer : 0.348839527028613
# stats_beta_css - mtnucratio : 0.15953250084031226
# stats_beta_css - sexdeterrmine_prep : 0.10250115416114923
# stats_beta_css - sexdeterrmine : 0.19748141801184996
# stats_beta_css - nuclear_contamination : 0.1628447741792435
# stats_beta_css - print_nuclear_contamination : 0.3306246746990011
# stats_beta_css - metagenomic_complexity_filter : 0.18006942955409405
# stats_beta_css - malt : 0.38837124671907447
# stats_beta_css - maltextract : 0.3515364109093766
# stats_beta_css - decomp_kraken : 0.03287921334042406
# stats_beta_css - kraken : 0.2196722493879216
# stats_beta_css - kraken_parse : 0.07555433904227277
# stats_beta_css - kraken_merge : 0.2144190880610615
# stats_beta_css - output_documentation : 0.29760434189687757
# stats_beta_css - get_software_versions : 0.028429287775453064
# stats_beta_css - multiqc : 0.1852444670836579
# stats_desc_comp - unzip_reference : 0.11634235460787601
# stats_desc_comp - makeBWAIndex : 0.1292940826255326
# stats_desc_comp - makeBT2Index : 0.12522600429144376
# stats_desc_comp - makeFastaIndex : 0.1995370806485664
# stats_desc_comp - makeSeqDict : 0.16003139360604754
# stats_desc_comp - convertBam : 0.07440848060379363
# stats_desc_comp - indexinputbam : 0.12028999466752811
# stats_desc_comp - fastqc : 0.09062265854128648
# stats_desc_comp - fastp : 0.12388977286769112
# stats_desc_comp - adapter_removal : 0.1460146994756867
# stats_desc_comp - post_ar_fastq_trimming : 0.14987934828941518
# stats_desc_comp - lanemerge : 0.09768157610198475
# stats_desc_comp - lanemerge_hostremoval_fastq : 0.09585488181997598
# stats_desc_comp - fastqc_after_clipping : 0.19636198549866538
# stats_desc_comp - bwa : 0.1330285760314675
# stats_desc_comp - bwamem : 0.09885969768999128
# stats_desc_comp - circulargenerator : 0.2467447634042183
# stats_desc_comp - circularmapper : 0.1678381942396977
# stats_desc_comp - bowtie2 : 0.12593560284396227
# stats_desc_comp - hostremoval_input_fastq : 0.15291896396271218
# stats_desc_comp - seqtype_merge : 0.07735507357492039
# stats_desc_comp - samtools_flagstat : 0.1501364844321511
# stats_desc_comp - samtools_filter : 0.09592179397523143
# stats_desc_comp - samtools_flagstat_after_filter : 0.1364761895619286
# stats_desc_comp - endorSpy : 0.11444344085094435
# stats_desc_comp - dedup : 0.07922240438735809
# stats_desc_comp - markduplicates : 0.07701344061057373
# stats_desc_comp - library_merge : 0.09124896248020345
# stats_desc_comp - preseq : 0.2441762666859996
# stats_desc_comp - bedtools : 0.11932039207878273
# stats_desc_comp - damageprofiler : 0.11859225534809067
# stats_desc_comp - mapdamage_rescaling : 0.1467116809884
# stats_desc_comp - pmdtools : 0.15828813703471717
# stats_desc_comp - bam_trim : 0.17029464411326342
# stats_desc_comp - additional_library_merge : 0.07269172859778784
# stats_desc_comp - qualimap : 0.18581650554303986
# stats_desc_comp - genotyping_ug : 0.15829532990680256
# stats_desc_comp - genotyping_hc : 0.24062361417205835
# stats_desc_comp - genotyping_freebayes : 0.2535530314090019
# stats_desc_comp - genotyping_pileupcaller : 0.16830013726238974
# stats_desc_comp - eigenstrat_snp_coverage : 0.10301799131418142
# stats_desc_comp - genotyping_angsd : 0.1713662899969744
# stats_desc_comp - bcftools_stats : 0.14705683785056792
# stats_desc_comp - vcf2genome : 0.17629210432719225
# stats_desc_comp - multivcfanalyzer : 0.24259057828953837
# stats_desc_comp - mtnucratio : 0.12415070531827045
# stats_desc_comp - sexdeterrmine_prep : 0.10699037812458444
# stats_desc_comp - sexdeterrmine : 0.15928322891937935
# stats_desc_comp - nuclear_contamination : 0.1339129768838513
# stats_desc_comp - print_nuclear_contamination : 0.25773809732482694
# stats_desc_comp - metagenomic_complexity_filter : 0.13951700224183738
# stats_desc_comp - malt : 0.28293999731449143
# stats_desc_comp - maltextract : 0.25904804946156834
# stats_desc_comp - decomp_kraken : 0.04810333303829746
# stats_desc_comp - kraken : 0.17074114828136863
# stats_desc_comp - kraken_parse : 0.09033618819106862
# stats_desc_comp - kraken_merge : 0.17723084862834773
# stats_desc_comp - output_documentation : 0.24599992222050424
# stats_desc_comp - get_software_versions : 0.019724798154737867
# stats_desc_comp - multiqc : 0.18037640033930336
# report - unzip_reference : 0.06337902173328767
# report - makeBWAIndex : 0.1411865988891504
# report - makeBT2Index : 0.13609106484803338
# report - makeFastaIndex : 0.25411404184213954
# report - makeSeqDict : 0.18738163001289906
# report - convertBam : 0.04290957489054475
# report - indexinputbam : 0.08653391156721703
# report - fastqc : 0.07434388027250971
# report - fastp : 0.1181862594964895
# report - adapter_removal : 0.1739554453295636
# report - post_ar_fastq_trimming : 0.18352084557044931
# report - lanemerge : 0.0910211970829325
# report - lanemerge_hostremoval_fastq : 0.045613289770676635
# report - fastqc_after_clipping : 0.17963556586703971
# report - bwa : 0.17230164600209988
# report - bwamem : 0.09320180124936774
# report - circulargenerator : 0.2436460511159198
# report - circularmapper : 0.18398530938896263
# report - bowtie2 : 0.1490806479820892
# report - hostremoval_input_fastq : 0.1380696355586831
# report - seqtype_merge : 0.03731868986905654
# report - samtools_flagstat : 0.11692417373376629
# report - samtools_filter : 0.12504810337335995
# report - samtools_flagstat_after_filter : 0.13253558859227885
# report - endorSpy : 0.13327748653026006
# report - dedup : 0.07344280058045174
# report - markduplicates : 0.07097289269084656
# report - library_merge : 0.06947641055033145
# report - preseq : 0.3154911788607013
# report - bedtools : 0.09958384711905124
# report - damageprofiler : 0.12012443703773808
# report - mapdamage_rescaling : 0.14648010036998227
# report - pmdtools : 0.1812795916353593
# report - bam_trim : 0.1841339632597027
# report - additional_library_merge : 0.066747297444469
# report - qualimap : 0.1751600636801896
# report - genotyping_ug : 0.17419350963500538
# report - genotyping_hc : 0.25716218970012905
# report - genotyping_freebayes : 0.22610302182660338
# report - genotyping_pileupcaller : 0.14783868906758277
# report - eigenstrat_snp_coverage : 0.10892960960932163
# report - genotyping_angsd : 0.1641660415107284
# report - bcftools_stats : 0.1350045746123632
# report - vcf2genome : 0.2076662474794633
# report - multivcfanalyzer : 0.22420597512233909
# report - mtnucratio : 0.12530831001760484
# report - sexdeterrmine_prep : 0.06086461173315817
# report - sexdeterrmine : 0.14170165444020136
# report - nuclear_contamination : 0.12006475644905304
# report - print_nuclear_contamination : 0.21575685595395352
# report - metagenomic_complexity_filter : 0.1384095144155453
# report - malt : 0.3381152916397304
# report - maltextract : 0.2951887921171286
# report - decomp_kraken : 0.011258019801558845
# report - kraken : 0.21494857461286138
# report - kraken_parse : 0.07633907792651376
# report - kraken_merge : 0.1702850612757473
# report - output_documentation : 0.17708482019513672
# report - get_software_versions : 0.04612929902778091
# report - multiqc : 0.08214252961923332
# compress_result - unzip_reference : 0.11805026273648164
# compress_result - makeBWAIndex : 0.1603476225605486
# compress_result - makeBT2Index : 0.15536060426665319
# compress_result - makeFastaIndex : 0.2734669519957839
# compress_result - makeSeqDict : 0.20964816666143107
# compress_result - convertBam : 0.07884571468566487
# compress_result - indexinputbam : 0.13352559951036994
# compress_result - fastqc : 0.2450337226637065
# compress_result - fastp : 0.14583285374758984
# compress_result - adapter_removal : 0.20929231246412272
# compress_result - post_ar_fastq_trimming : 0.20593652192683892
# compress_result - lanemerge : 0.11337389946884521
# compress_result - lanemerge_hostremoval_fastq : 0.09216697116748225
# compress_result - fastqc_after_clipping : 0.30857142449997216
# compress_result - bwa : 0.18632480901925577
# compress_result - bwamem : 0.1197583803831902
# compress_result - circulargenerator : 0.30449480976146287
# compress_result - circularmapper : 0.21706377598750579
# compress_result - bowtie2 : 0.16776481964515774
# compress_result - hostremoval_input_fastq : 0.17341715745268185
# compress_result - seqtype_merge : 0.07218650488727127
# compress_result - samtools_flagstat : 0.15596010367429863
# compress_result - samtools_filter : 0.13661596473579646
# compress_result - samtools_flagstat_after_filter : 0.1623287724392626
# compress_result - endorSpy : 0.1359619281879024
# compress_result - dedup : 0.08946484895358194
# compress_result - markduplicates : 0.09611965456395627
# compress_result - library_merge : 0.09799109414351768
# compress_result - preseq : 0.3576633017136062
# compress_result - bedtools : 0.13763330288757042
# compress_result - damageprofiler : 0.1429299215967994
# compress_result - mapdamage_rescaling : 0.18140222337213835
# compress_result - pmdtools : 0.20666048593507758
# compress_result - bam_trim : 0.22220394515953878
# compress_result - additional_library_merge : 0.08669318010440841
# compress_result - qualimap : 0.2291035597863807
# compress_result - genotyping_ug : 0.2038267416154192
# compress_result - genotyping_hc : 0.3036884938759411
# compress_result - genotyping_freebayes : 0.29430266803238964
# compress_result - genotyping_pileupcaller : 0.18747368862741842
# compress_result - eigenstrat_snp_coverage : 0.12359926353073657
# compress_result - genotyping_angsd : 0.2072863275290226
# compress_result - bcftools_stats : 0.16312486371264073
# compress_result - vcf2genome : 0.2390875229014326
# compress_result - multivcfanalyzer : 0.28995752480608605
# compress_result - mtnucratio : 0.15431876218887738
# compress_result - sexdeterrmine_prep : 0.11549967209783182
# compress_result - sexdeterrmine : 0.17873668725404723
# compress_result - nuclear_contamination : 0.16649153476726317
# compress_result - print_nuclear_contamination : 0.29525149931279226
# compress_result - metagenomic_complexity_filter : 0.16773359494802656
# compress_result - malt : 0.37957423912923055
# compress_result - maltextract : 0.3436297307924359
# compress_result - decomp_kraken : 0.04910158824109193
# compress_result - kraken : 0.2176838844620977
# compress_result - kraken_parse : 0.08687590217794194
# compress_result - kraken_merge : 0.19632282089679112
# compress_result - output_documentation : 0.259813208029365
# compress_result - get_software_versions : 0.022376978833945783
# compress_result - multiqc : 0.14750254193376777
